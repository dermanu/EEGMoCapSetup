# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Lab_Measurements007.csv')
df = pd.melt(df)
print(df.describe())
# Out:
#                value
# count  243000.000000
# mean        2.163202
# std        16.681168
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       241.000000

# %%
df.plot()
# Out:
# <Axes: >

# %%
# Plot the data using Matplotlib
plt.figure(figsize=(10, 6))  # Set the figure size (optional)
plt.plot(df[index], df['value'], marker='o', linestyle='-', color='b')
plt.title('CSV Data as a Graph')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid(True)  # Add grid lines (optional)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 # Plot the data using Matplotlib
#       2 plt.figure(figsize=(10, 6))  # Set the figure size (optional)
# ----> 3 plt.plot(df[index], df['value'], marker='o', linestyle='-', color='b')
#       4 plt.title('CSV Data as a Graph')
#       5 plt.xlabel('X-axis')
#
# NameError: name 'index' is not defined
